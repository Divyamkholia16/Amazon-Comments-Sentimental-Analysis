# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import nltk

# %%
df=pd.read_csv("Reviews.csv")

# %%
print(df.shape)
df = df.head(1000)
print(df.shape)
# Out:
# (568454, 10)
# (1000, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# #Quick Eda

# %%
ax=df['Score'].value_counts().sort_index().plot(kind='bar',title="Review count by stars",figsize=(12,6))
ax.set_xlabel("Review stars")
plt.show()

# %% [markdown]
# #BASIC NLTK

# %%
example=df['Text'][4]
print(example)
# Out:
# Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.

# %%
tokens=nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['Great', 'taffy', 'at', 'a', 'great', 'price', '.', 'There', 'was', 'a']

# %%
tagged=nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('Great', 'NNP'),
#  ('taffy', 'NN'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('price', 'NN'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('was', 'VBD'),
#  ('a', 'DT')]

# %% [markdown]
# #abbreviation table
#
# ![Screenshot%20%285%29.png](attachment:Screenshot%20%285%29.png)

# %% [markdown]
# #Step 1 Using Vader(tool of nltk for doing sentimental analysis)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
sa= SentimentIntensityAnalyzer()

# %%
sa.polarity_scores(example)
# Out:
# {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.9468}

# %% [markdown]
# #Run The polarity score on entire data frame

# %%
res={}   #Use Dictionary to store values
for i,row in tqdm(df.iterrows(),total=len(df)):
    text=row['Text']
    myid=row['Id']
    res[myid]=sa.polarity_scores(text)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
res
# Out:
# {1: {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441},
#  2: {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.5664},
#  3: {'neg': 0.091, 'neu': 0.754, 'pos': 0.155, 'compound': 0.8265},
#  4: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  5: {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.9468},
#  6: {'neg': 0.029, 'neu': 0.809, 'pos': 0.163, 'compound': 0.883},
#  7: {'neg': 0.034, 'neu': 0.693, 'pos': 0.273, 'compound': 0.9346},
#  8: {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9487},
#  9: {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.6369},
#  10: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.8313},
#  11: {'neg': 0.017, 'neu': 0.846, 'pos': 0.137, 'compound': 0.9746},
#  12: {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.7579},
#  13: {'neg': 0.031, 'neu': 0.923, 'pos': 0.046, 'compound': 0.296},
#  14: {'neg': 0.0, 'neu': 0.355, 'pos': 0.645, 'compound': 0.9466},
# ...

# %%
vaders=pd.DataFrame(res).T
vaders=vaders.reset_index().rename(columns={'index':'Id'})
vaders=vaders.merge(df,how='left')

# %%
#Now  we have sentiment score and metdata
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# ...

# %% [markdown]
# #Plotting the bar wtrt Vaders and score

# %%
ax=sns.barplot(data=vaders,x='Score',y='compound')
ax.set_title("Compound score by Amazon Stars")
plt.show()

# %%
fig,axs=plt.subplots(1,3,figsize=(15,3))
sns.barplot(data=vaders,x='Score',y='pos',ax=axs[0])
sns.barplot(data=vaders,x='Score',y='neu',ax=axs[1])
sns.barplot(data=vaders,x='Score',y='neg',ax=axs[2])
axs[0].set_title("Positive")
axs[1].set_title("Neutral")
axs[2].set_title("Negitive")
plt.show()

# %% [markdown]
# #Using Roberta Pretrained Model

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %% [markdown]
# #For Retrained models refer to (https://huggingface.co/models)

# %%
model="cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model)
model = AutoModelForSequenceClassification.from_pretrained(model)

# %%
encoded_text=tokenizer(example,return_tensors='pt')
output=model(**encoded_text)
Scores=output[0][0].detach().numpy()
Scores=softmax(Scores)
Scores
# Out:
# array([0.00163473, 0.01030247, 0.9880629 ], dtype=float32)

# %%
Scores_dict={
    'roberta_neg':Scores[0],
    'roberta_neu':Scores[1],
    'roberta_pos':Scores[2]
}
print(Scores_dict)
# Out:
# {'roberta_neg': 0.001634728, 'roberta_neu': 0.010302468, 'roberta_pos': 0.9880629}

# %%
def polarity_scores_roberta(example):
    encoded_text=tokenizer(example,return_tensors='pt')
    output=model(**encoded_text)
    Scores=output[0][0].detach().numpy()
    Scores=softmax(Scores)
    Scores_dict={
        'roberta_neg':Scores[0],
        'roberta_neu':Scores[1],
        'roberta_pos':Scores[2]
    }
    return Scores_dict

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sa.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187
# Broke for id 529
# Broke for id 540
# Broke for id 746
# Broke for id 863

# %%
result_df=pd.DataFrame(res).T
result_df=result_df.reset_index().rename(columns={'index':'Id'})
result_df=result_df.merge(df,how='left')

# %%
result_df.head()
# Out:
#    Id  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 0   1      0.000      0.695      0.305          0.9441     0.009624
# 1   2      0.138      0.862      0.000         -0.5664     0.508986
# 2   3      0.091      0.754      0.155          0.8265     0.003229
# 3   4      0.000      1.000      0.000          0.0000     0.002295
# 4   5      0.000      0.552      0.448          0.9468     0.001635
#
#    roberta_neu  roberta_pos   ProductId          UserId  \
# 0     0.049980     0.940395  B001E4KFG0  A3SGXH7AUHU8GW
# 1     0.452414     0.038600  B00813GRG4  A1D87F6ZCVE5NK
# 2     0.098067     0.898704  B000LQOCH0   ABXLMWJIXXAIN
# 3     0.090219     0.907486  B000UA0QIQ  A395BORC6FGVXV
# 4     0.010302     0.988063  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# ...

# %% [markdown]
# #Compare Scores between models

# %% [markdown]
# #Combine and Compare

# %%
result_df.columns
# Out:
# Index(['Id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
sns.pairplot(data=result_df,
            vars=['vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
       'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',palette='tab10')
plt.show()

# %% [markdown]
# #Review Examples
# #Postive 1 star reviews and Negative 5 star reviews

# %%
result_df.query('Score==1').sort_values('roberta_pos',ascending=False)['Text'].values[0]
# Out:
# "I just wanted to post here that I found small bits of plastic in this food as I was feeding my 9 month old.  Plastic!!! in food!!!! baby food!!!  So please be careful if you buy this or are considering it.<br /><br />My daughter LOVES this food-- it's actually her favorite.  This is the first time we have noticed plastic in it in over 2 months."

# %%
result_df.query('Score==1').sort_values('vader_pos',ascending=False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'

# %% [markdown]
# #Negative sentiment 5 star reviews

# %%
result_df.query('Score==5').sort_values('roberta_neg',ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %%
result_df.query('Score==5').sort_values('vader_neg',ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %% [markdown]
# #USING TRANSFORMERS PIPELINE

# %%
from transformers import pipeline
sent_pipeline=("sentiment-analysis")

# %%
sent_pipeline('boo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9612/4018849762.py in <module>
# ----> 1 sent_pipeline('boo')
#
# TypeError: 'str' object is not callable
